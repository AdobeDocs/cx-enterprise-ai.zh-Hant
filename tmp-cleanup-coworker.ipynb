# %% [markdown]
# # Cleanup duplicate Coworker files
#
# Remove the duplicate analytics-chat file from the chat subdirectory.

# %%
from pathlib import Path
path = Path(r'c:/Users/mfrei/Documents/GitHub/cx-enterprise-ai.en/help/coworker/chat/analytics-chat.md')
print('Exists before:', path.exists())
if path.exists():
    path.unlink()
    print('Deleted', path)
else:
    print('File not found, nothing to delete')
print('Exists after:', path.exists())
